# %% [markdown]
# # Imports

# %%
import pandas as pd
import numpy as np
import os

## repeated printouts
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %% [markdown]
# ## Read in data and make sure relevant columns are string/character
#
# - San Diego data: `naics_code` and `account_key`
# - NAICS details data: `naics`
#
# Run code below; if pulling from github, pathname should be fine; if working elsewhere may need to edit path name at read in

# %%
# uncomment if u need to find your path: os.getcwd()
SD = sd_df = pd.read_csv("../public_data/sd_df.csv")
NA = naics_df = pd.read_csv("../public_data/naics_df.csv")

# %%
cols_sd_use = ["naics_code", "account_key"]
cols_naics_use = ["naics"]

sd_df[cols_sd_use] = sd_df[cols_sd_use].astype(str)
naics_df[cols_naics_use] = naics_df[cols_naics_use].astype(str)

sd_df.dtypes
naics_df.dtypes
sd_df.head()
naics_df.head()
# Out:
# account_key          object
# dba_name             object
# council_district     object
# naics_code           object
# naics_description    object
# naics_nchar           int64
# dtype: object
# naics                object
# naics_description    object
# dtype: object
#   account_key                                      dba_name council_district  \
# 0  1974000448                             ERNST & YOUNG LLP             cd_1
# 1  1974011093  HECHT SOLBERG ROBINSON GOLDBERG & BAGLEY LLP             cd_3
# 2  1978039819                                    RSM US LLP             cd_1
# 3  1978042092               THORSNES BARTOLOTTA MCGUIRE LLP             cd_3
# 4  1979046817                       KORENIC & WOJDOWSKI LLP             cd_7
#
#   naics_code                              naics_description  naics_nchar
# 0     541211        OFFICES OF CERTIFIED PUBLIC ACCOUNTANTS            6
# 1       5411                                 LEGAL SERVICES            4
# 2     541211        OFFICES OF CERTIFIED PUBLIC ACCOUNTANTS            6
# 3       5411                                 LEGAL SERVICES            4
# 4       5412  ACCOUNTING/TAX PREP/BOOKKEEP/PAYROLL SERVICES            4
#     naics                 naics_description
# 0  111140                     Wheat Farming
# 1  111160                      Rice Farming
# 2  111150                      Corn Farming
# 3  111110                   Soybean Farming
# 4  111120  Oilseed (except Soybean) Farming

# %% [markdown]
# ## "Inner join"- retain only San Diego businesses with details on their NAICS code
#
# - Use the `naics_code` column in the San Diego business data as the join key
# - Use the `naics` column in the NAICS code details data as the join key
#
# - Do an inner join of the San Diego data onto the NAICS code details using these join keys
# - After the inner join, print some examples of San Diego businesses lost in the merge
# - Use value_counts() on the `naics_nchar` column in the San Diego data to see why they might have gotten lost

# %%
NA.merge(SD, right_on = 'naics_code', left_on = 'naics', how = "inner")

lost_businesses = SD[~SD['naics_code'].isin(SD_NAICS['naics_code'])]

SD.naics_nchar.value_counts()
# Out:
#      naics                                naics_description_x account_key  \
# 0   311999         All Other Miscellaneous Food Manufacturing  2020007786
# 1   311999         All Other Miscellaneous Food Manufacturing  2020007786
# 2   311999         All Other Miscellaneous Food Manufacturing  2020007786
# 3   311999         All Other Miscellaneous Food Manufacturing  2020007786
# 4   311999         All Other Miscellaneous Food Manufacturing  2020007786
# 5   321999  All Other Miscellaneous Wood Product Manufactu...  1995007398
# 6   321999  All Other Miscellaneous Wood Product Manufactu...  1995007398
# 7   321999  All Other Miscellaneous Wood Product Manufactu...  1995007398
# 8   321999  All Other Miscellaneous Wood Product Manufactu...  1995007398
# 9   321999  All Other Miscellaneous Wood Product Manufactu...  1995007398
# 10  321999  All Other Miscellaneous Wood Product Manufactu...  1995007398
# 11  453998  All Other Miscellaneous Store Retailers (excep...  2003001470
# 12  453998  All Other Miscellaneous Store Retailers (excep...  2003001470
# 13  453998  All Other Miscellaneous Store Retailers (excep...  2003001470
# 20         THE SUMMIT AT POINT LOMA APARTMENTS             cd_2     531311
# 21                                       ARIEL             cd_3     531311
# 22               BEYER BOULEVARD APARTMENTS LP             cd_8     531311
# 23                ALTMAN INVESTMENT COMPANY LP             cd_1     531312
# 24                  LAPIZ PROPERTIES GROUP LTD             cd_1     531312
# 25                 MASSEY WEHR AND COMPANY LLP             cd_1     541213
# 26               ALVAREZ TAX & ACCOUNTING  LLP             cd_6     541213
# 27                       STARDUST FLOAT SPA LP             cd_2     812199
# 28          ALLIED UNIVERSAL SECURITY SERVICES             cd_5     561612
# 29            ROBBINS GELLER RUDMAN & DOWD LLP             cd_3     541199
# 30                         SLATER & TRUXAW LLP             cd_1     541199
# 31                         CONNOR & CUNDEL LLP             cd_3     541199
# 32                       WENTHUR LAW GROUP LLP             cd_2     541199
# 33                          INSTANT SMOG CHECK             cd_6     811198
# 34                          INSTANT SMOG CHECK             cd_6     811198
# 35                          INSTANT SMOG CHECK             cd_6     811198
# 36                                  PADRES L P             cd_3     711211
# 37                  MOTHER TO MOTHER MIDWIFERY             cd_3     621399
# 38                  MOTHER TO MOTHER MIDWIFERY             cd_3     621399
# 39                           ERNST & YOUNG LLP             cd_1     541211
# 40                                  RSM US LLP             cd_1     541211
# 41            MAX L. PERLATTI & ASSOCIATES LLP             cd_2     541211
# 42                                    RBTK LLP             cd_6     541211
# 43                                CWGB&S CPAS              cd_3     541211
# 44                        DELSEN & COMPANY LLP             cd_6     541211
# 45         GUERRERO JIMENEZ DIAZ & COMPANY LLP             cd_3     541211
# 46                              MOSS ADAMS LLP             cd_7     541211
# 47                                 BDO USA LLP             cd_1     541211
# 48                        SWENSON ADVISORS LLP             cd_3     541211
# 49                       MURRILL & GERBINO LLP             cd_1     541211
# 50                    STEES WALKER COMPANY LLP             cd_5     541211
# 51                        REIWA ACCOUNTING LLP             cd_3     541211
#
#                               naics_description_y  naics_nchar
# 0                ALL OTHER MISCELLANEOUS FOOD MFG            6
# 1                ALL OTHER MISCELLANEOUS FOOD MFG            6
# 2                ALL OTHER MISCELLANEOUS FOOD MFG            6
# 3                ALL OTHER MISCELLANEOUS FOOD MFG            6
# 4                ALL OTHER MISCELLANEOUS FOOD MFG            6
# 5        ALL OTHER MISCELLANEOUS WOOD PRODUCT MFG            6
# 6        ALL OTHER MISCELLANEOUS WOOD PRODUCT MFG            6
# 7        ALL OTHER MISCELLANEOUS WOOD PRODUCT MFG            6
# 8        ALL OTHER MISCELLANEOUS WOOD PRODUCT MFG            6
# 9        ALL OTHER MISCELLANEOUS WOOD PRODUCT MFG            6
# 10       ALL OTHER MISCELLANEOUS WOOD PRODUCT MFG            6
# 11   ALL OTHER MISC STORE RETAILERS (EXC TOBACCO)            6
# 12   ALL OTHER MISC STORE RETAILERS (EXC TOBACCO)            6
# 13   ALL OTHER MISC STORE RETAILERS (EXC TOBACCO)            6
# 14   ALL OTHER MISC STORE RETAILERS (EXC TOBACCO)            6
# 15                               CONSUMER LENDING            6
# 16  MISCELLANEOUS FINANCIAL INVESTMENT ACTIVITIES            6
# 17  MISCELLANEOUS FINANCIAL INVESTMENT ACTIVITIES            6
# 18  MISCELLANEOUS FINANCIAL INVESTMENT ACTIVITIES            6
# 19  MISCELLANEOUS FINANCIAL INVESTMENT ACTIVITIES            6
# 20                  RESIDENTIAL PROPERTY MANAGERS            6
# 21                  RESIDENTIAL PROPERTY MANAGERS            6
# 22                  RESIDENTIAL PROPERTY MANAGERS            6
# 23               NONRESIDENTIAL PROPERTY MANAGERS            6
# 24               NONRESIDENTIAL PROPERTY MANAGERS            6
# 25                       TAX PREPARATION SERVICES            6
# 26                       TAX PREPARATION SERVICES            6
# 27                   OTHER PERSONAL CARE SERVICES            6
# 28              SECURITY GUARDS & PATROL SERVICES            6
# 29                       ALL OTHER LEGAL SERVICES            6
# 30                       ALL OTHER LEGAL SERVICES            6
# 31                       ALL OTHER LEGAL SERVICES            6
# 32                       ALL OTHER LEGAL SERVICES            6
# 33                       ALL OTHER AUTOMOTIVE R&M            6
# 34                       ALL OTHER AUTOMOTIVE R&M            6
# 35                       ALL OTHER AUTOMOTIVE R&M            6
# 36                         SPORTS TEAMS AND CLUBS            6
# 37   OFFICES OF ALL OTH MISC HEALTH PRACTITIONERS            6
# 38   OFFICES OF ALL OTH MISC HEALTH PRACTITIONERS            6
# 39        OFFICES OF CERTIFIED PUBLIC ACCOUNTANTS            6
# 40        OFFICES OF CERTIFIED PUBLIC ACCOUNTANTS            6
# 41        OFFICES OF CERTIFIED PUBLIC ACCOUNTANTS            6
# 42        OFFICES OF CERTIFIED PUBLIC ACCOUNTANTS            6
# 43        OFFICES OF CERTIFIED PUBLIC ACCOUNTANTS            6
# 44        OFFICES OF CERTIFIED PUBLIC ACCOUNTANTS            6
# 45        OFFICES OF CERTIFIED PUBLIC ACCOUNTANTS            6
# 46        OFFICES OF CERTIFIED PUBLIC ACCOUNTANTS            6
# 47        OFFICES OF CERTIFIED PUBLIC ACCOUNTANTS            6
# 48        OFFICES OF CERTIFIED PUBLIC ACCOUNTANTS            6
# 49        OFFICES OF CERTIFIED PUBLIC ACCOUNTANTS            6
# 50        OFFICES OF CERTIFIED PUBLIC ACCOUNTANTS            6
# 51        OFFICES OF CERTIFIED PUBLIC ACCOUNTANTS            6
# naics_nchar
# 5    150
# 4     89
# 6     49
# 3     42
# 2     23
# Name: count, dtype: int64

# %% [markdown]
# ## "Left join"- retain all sd businesses even if naics code isn't in `naics_df`
#
# - Using the same join keys as above, and treating the San Diego businesses as the left hand side data, left join the naics code details onto the San Diego businesses
# - Use the `indicator` argument within merge to create an indicator, `naics_merge_status`, to help with later merge diagnostics and examine sample of ones that didn't merge
# - Use the `suffixes` argument within merge to add `_sd` as the left suffix, `_census` as the right suffix
# - Use `naics_merge_status` in the merged result to look at a sample of San Diego businesses that weren't matched with `naics_df`

# %%
df_left_join = sd_df.merge(naics_df, 
                           left_on = "naics_code", 
                           right_on="naics", 
                           how="left", 
                           suffixes=("_sd", "_census"), 
                           indicator="naics_merge_status")
df_left_join.head()
df_left_join[df_left_join["naics_merge_status"] != "both"].head()
# Out:
#   account_key                                      dba_name council_district  \
# 0  1974000448                             ERNST & YOUNG LLP             cd_1
# 1  1974011093  HECHT SOLBERG ROBINSON GOLDBERG & BAGLEY LLP             cd_3
# 2  1978039819                                    RSM US LLP             cd_1
# 3  1978042092               THORSNES BARTOLOTTA MCGUIRE LLP             cd_3
# 4  1979046817                       KORENIC & WOJDOWSKI LLP             cd_7
#
#   naics_code                           naics_description_sd  naics_nchar  \
# 0     541211        OFFICES OF CERTIFIED PUBLIC ACCOUNTANTS            6
# 1       5411                                 LEGAL SERVICES            4
# 2     541211        OFFICES OF CERTIFIED PUBLIC ACCOUNTANTS            6
# 3       5411                                 LEGAL SERVICES            4
# 4       5412  ACCOUNTING/TAX PREP/BOOKKEEP/PAYROLL SERVICES            4
#
#     naics                 naics_description_census naics_merge_status
# 0  541211  Offices of Certified Public Accountants               both
# 1     NaN                                      NaN          left_only
# 2  541211  Offices of Certified Public Accountants               both
# 3     NaN                                      NaN          left_only
# 4     NaN                                      NaN          left_only
#   account_key                                      dba_name council_district  \
# 1  1974011093  HECHT SOLBERG ROBINSON GOLDBERG & BAGLEY LLP             cd_3
# 3  1978042092               THORSNES BARTOLOTTA MCGUIRE LLP             cd_3
# 4  1979046817                       KORENIC & WOJDOWSKI LLP             cd_7
# 5  1979053082    GRIMM VRANJES GREER STEPHAN & BRIDGMAN LLP             cd_3
# 6  1981000840                          BENINK & SLAVENS LLP             cd_7
#
#   naics_code                           naics_description_sd  naics_nchar  \
# 1       5411                                 LEGAL SERVICES            4
# 3       5411                                 LEGAL SERVICES            4
# 4       5412  ACCOUNTING/TAX PREP/BOOKKEEP/PAYROLL SERVICES            4
# 5       5411                                 LEGAL SERVICES            4
# 6       5411                                 LEGAL SERVICES            4
#
#   naics naics_description_census naics_merge_status
# 1   NaN                      NaN          left_only
# 3   NaN                      NaN          left_only
# 4   NaN                      NaN          left_only
# 5   NaN                      NaN          left_only
# 6   NaN                      NaN          left_only

# %% [markdown]
# ## Use group by and agg to see if there are differences in merge rates by area
#
# - Using the left-joined dataframe created in previous step, create a boolean indicator, `is_lost`, that equals `True` if the merge indicator is equal to "left_only" (and is otherwise false)
# - Find the proportion of businesses by council district that were lost in the left join (SD businesses that failed to match to `naics_df`). To do this, group by `council_district` and use the shortcut of taking the mean of the `is_lost` indicator to find the proportions lost by `council_district`.

# %%
#left_SD_NAICS["is_lost"] = left_SD_NAICS["naics_merge_status"].apply(lambda is_lost: True if is_lost == "left_only" else False)

df_left_join["is_lost"] = df_left_join["naics_merge_status"] == "left_only"
df_left_join.head()
# Prop of businesses lost in left join
df_left_join.groupby("council_district").mean("is_lost")
# Out:
#   account_key                                      dba_name council_district  \
# 0  1974000448                             ERNST & YOUNG LLP             cd_1
# 1  1974011093  HECHT SOLBERG ROBINSON GOLDBERG & BAGLEY LLP             cd_3
# 2  1978039819                                    RSM US LLP             cd_1
# 3  1978042092               THORSNES BARTOLOTTA MCGUIRE LLP             cd_3
# 4  1979046817                       KORENIC & WOJDOWSKI LLP             cd_7
#
#   naics_code                           naics_description_sd  naics_nchar  \
# 0     541211        OFFICES OF CERTIFIED PUBLIC ACCOUNTANTS            6
# 1       5411                                 LEGAL SERVICES            4
# 2     541211        OFFICES OF CERTIFIED PUBLIC ACCOUNTANTS            6
# 3       5411                                 LEGAL SERVICES            4
# 4       5412  ACCOUNTING/TAX PREP/BOOKKEEP/PAYROLL SERVICES            4
#
#     naics                 naics_description_census naics_merge_status  is_lost
# 0  541211  Offices of Certified Public Accountants               both    False
# 1     NaN                                      NaN          left_only     True
# 2  541211  Offices of Certified Public Accountants               both    False
# 3     NaN                                      NaN          left_only     True
# 4     NaN                                      NaN          left_only     True
#                   naics_nchar   is_lost
# council_district
# cd_1                 4.447761  0.880597
# cd_2                 4.434783  0.804348
# cd_3                 4.750000  0.812500
# cd_4                 3.750000  1.000000
# cd_5                 4.291667  0.916667
# cd_6                 4.508772  0.859649
# cd_7                 4.621622  0.918919
# cd_8                 4.000000  0.933333
# cd_9                 4.250000  1.000000

# %% [markdown]
# ## Optional challenge exercise: add lagging 0's and see if merge rate improves
#
# You noticed earlier that a big reason for non-matches is that the San Diego tax certificate NAICS codes were often less than six digits long, while the Census ones were always 6 digits.
#
# You wonder if this is an issue where 0's in some of the SD's data naics codes got cut off (eg 540000 became 54), and if so whether adding these lagging zeros would improve the merge rate in a left join.
#
# - Pad the `naics_code` column in `sd_df` with 0's to get that column up to 6-digits, using one of two approaches:
#   1. `str.pad` in pandas (https://pandas.pydata.org/docs/reference/api/pandas.Series.str.pad.html)
#   2. for more of a challenge, write your own function! It should check the # of digits in the naics code string and pad it with 0's at the end up to 6 digits. To execute your function, use row-wise apply: `df.apply(lambda row: funcname(row.column), axis=1)`.
# - Perform the same left join as above and see how the match rate changes
# - Create an indicator variable--`is_new_match`---for new matches under the padded NAICS code; compare the `naics_description` column from San Diego versus Census in the new dataset for a sample of these new matches and comment on whether the padding seems to be correct

# %%
# your code here
